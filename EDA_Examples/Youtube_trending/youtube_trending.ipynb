# %%
import pandas as pd

# %%
# only to be used by those who are getting SSL Error
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
df = pd.read_csv("https://query.data.world/s/evaqrt2zzlif7stoa53otaysb6ybwk")
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc      17.14.11
# 1  10L1hZ9qa58      17.14.11
# 2  N1vE8iiEg64      17.14.11
# 3  kJzGH0PVQHQ      17.14.11
# 4  il_pSa5l98w      17.14.11
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 2                     Eruma Saani | Tamil vs English      Eruma Saani
# 3  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
# 4  MCA (Middle Class Abbayi) TEASER - Nani,Sai Pa...         Dil Raju
#
#    category_id              publish_time  \
# 0            1  2017-11-12T12:20:39.000Z
# 1           24  2017-11-12T15:48:08.000Z
# 2           23  2017-11-12T07:08:48.000Z
# 3           24  2017-11-13T01:14:16.000Z
# 4           24  2017-11-10T04:29:50.000Z
#
#                                                 tags    views  likes  \
# ...

# %% [markdown]
# ## EDA
#
# - Data Understanding:
#     - Understand the data by getting in touch with the data provider.
# - Data Preparation:
#     - Check if the data is having all correct data type.
#     - Check for duplicates
#     - If duplicates, drop them
# - Data Analysis:
#     - Define the problem statement
#     - Make our analysis

# %% [markdown]
# **Identify the columns that have been loaded with incorrect Data Type**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37351 entries, 0 to 37350
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37351 non-null  object
#  1   trending_date           37351 non-null  object
#  2   title                   37351 non-null  object
#  3   channel_title           37351 non-null  object
#  4   category_id             37351 non-null  int64
#  5   publish_time            37351 non-null  object
#  6   tags                    37351 non-null  object
#  7   views                   37351 non-null  int64
#  8   likes                   37351 non-null  int64
#  9   dislikes                37351 non-null  int64
#  10  comment_count           37351 non-null  int64
#  11  thumbnail_link          37351 non-null  object
#  12  comments_disabled       37351 non-null  bool
#  13  ratings_disabled        37351 non-null  bool
# ...

# %% [markdown]
# - trending_date
# - publishe_date
#
# pandas datetime64 format

# %% [markdown]
# **Correct the data type of trending_date and publish_time to pandas datetime format**
#
# - pd.to_numeric(): This function converts a object columns(that should be loaded as int/float) as int/float
# - pd.to_datetime(): Converts a object columns(that should be loaded as DataTime format) to DateTime Format
# - https://strftime.org/

# %%
df.head(2)
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc      17.14.11
# 1  10L1hZ9qa58      17.14.11
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
#
#    category_id              publish_time  \
# 0            1  2017-11-12T12:20:39.000Z
# 1           24  2017-11-12T15:48:08.000Z
#
#                                                 tags    views  likes  \
# 0  sharry mann|"sharry mann new song"|"sharry man...  1096327  33966
# 1  Stylish Star Allu Arjun @ ChaySam Wedding Rece...   473988   2011
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0       798            882  https://i.ytimg.com/vi/kzwfHumJyYc/default.jpg
# 1       243            149  https://i.ytimg.com/vi/10L1hZ9qa58/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# ...

# %%
df['trending_date'] = pd.to_datetime(df['trending_date'], format = '%y.%d.%m')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37351 entries, 0 to 37350
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37351 non-null  object
#  1   trending_date           37351 non-null  datetime64[ns]
#  2   title                   37351 non-null  object
#  3   channel_title           37351 non-null  object
#  4   category_id             37351 non-null  int64
#  5   publish_time            37351 non-null  object
#  6   tags                    37351 non-null  object
#  7   views                   37351 non-null  int64
#  8   likes                   37351 non-null  int64
#  9   dislikes                37351 non-null  int64
#  10  comment_count           37351 non-null  int64
#  11  thumbnail_link          37351 non-null  object
#  12  comments_disabled       37351 non-null  bool
#  13  ratings_disabled        37351 non-null  bool
# ...

# %%
df['publish_time'] = pd.to_datetime(df['publish_time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37351 entries, 0 to 37350
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37351 non-null  object
#  1   trending_date           37351 non-null  datetime64[ns]
#  2   title                   37351 non-null  object
#  3   channel_title           37351 non-null  object
#  4   category_id             37351 non-null  int64
#  5   publish_time            37351 non-null  datetime64[ns, UTC]
#  6   tags                    37351 non-null  object
#  7   views                   37351 non-null  int64
#  8   likes                   37351 non-null  int64
#  9   dislikes                37351 non-null  int64
#  10  comment_count           37351 non-null  int64
#  11  thumbnail_link          37351 non-null  object
#  12  comments_disabled       37351 non-null  bool
#  13  ratings_disabled        37351 non-null  bool
# ...

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc    2017-11-14
# 1  10L1hZ9qa58    2017-11-14
# 2  N1vE8iiEg64    2017-11-14
# 3  kJzGH0PVQHQ    2017-11-14
# 4  il_pSa5l98w    2017-11-14
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 2                     Eruma Saani | Tamil vs English      Eruma Saani
# 3  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
# 4  MCA (Middle Class Abbayi) TEASER - Nani,Sai Pa...         Dil Raju
#
#    category_id              publish_time  \
# 0            1 2017-11-12 12:20:39+00:00
# 1           24 2017-11-12 15:48:08+00:00
# 2           23 2017-11-12 07:08:48+00:00
# 3           24 2017-11-13 01:14:16+00:00
# 4           24 2017-11-10 04:29:50+00:00
#
#                                                 tags    views  likes  \
# ...

# %% [markdown]
# **Extract the date component from the publish_time column and save it in a variable publish_date**

# %% [markdown]
# If we have a Pandas DateTime columns and if we wanted to extract any compoenent of date or time, then we may use .dt regressor

# %%
df['publish_date'] = pd.to_datetime(df['publish_time'].dt.date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37351 entries, 0 to 37350
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37351 non-null  object
#  1   trending_date           37351 non-null  datetime64[ns]
#  2   title                   37351 non-null  object
#  3   channel_title           37351 non-null  object
#  4   category_id             37351 non-null  int64
#  5   publish_time            37351 non-null  datetime64[ns, UTC]
#  6   tags                    37351 non-null  object
#  7   views                   37351 non-null  int64
#  8   likes                   37351 non-null  int64
#  9   dislikes                37351 non-null  int64
#  10  comment_count           37351 non-null  int64
#  11  thumbnail_link          37351 non-null  object
#  12  comments_disabled       37351 non-null  bool
#  13  ratings_disabled        37351 non-null  bool
# ...

# %% [markdown]
# **Is this data having any duplicted rows?**

# %%
df.shape
# Out:
# (37351, 18)

# %%
df.duplicated().sum()
# Out:
# 4263

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 37346     True
# 37347     True
# 37348     True
# 37349     True
# 37350     True
# Length: 37351, dtype: bool

# %%
df.iloc[[37346],:]
# Out:
#           video_id trending_date  \
# 37346  iNHecA3PJCo    2018-06-14
#
#                                                    title   channel_title  \
# 37346  फेकू आशिक़ - राजस्थान की सबसे शानदार कॉमेडी | ...  RDC Rajasthani
#
#        category_id              publish_time  \
# 37346           23 2018-06-13 08:01:11+00:00
#
#                                                     tags   views  likes  \
# 37346  twinkle vaishnav comedy|"twinkle vaishnav"|"tw...  214378   3291
#
#        dislikes  comment_count  \
# 37346       404            196
#
#                                        thumbnail_link  comments_disabled  \
# 37346  https://i.ytimg.com/vi/iNHecA3PJCo/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 37346             False                   False
#
#                                              description piblish_date  \
# 37346  PRG Music & RDC Rajasthani presents फेकू आशिक़...   2018-06-13
#
#       publish_date
# ...

# %%
df[df['video_id']=='iNHecA3PJCo']
# Out:
#           video_id trending_date  \
# 37224  iNHecA3PJCo    2018-06-14
# 37346  iNHecA3PJCo    2018-06-14
#
#                                                    title   channel_title  \
# 37224  फेकू आशिक़ - राजस्थान की सबसे शानदार कॉमेडी | ...  RDC Rajasthani
# 37346  फेकू आशिक़ - राजस्थान की सबसे शानदार कॉमेडी | ...  RDC Rajasthani
#
#        category_id              publish_time  \
# 37224           23 2018-06-13 08:01:11+00:00
# 37346           23 2018-06-13 08:01:11+00:00
#
#                                                     tags   views  likes  \
# 37224  twinkle vaishnav comedy|"twinkle vaishnav"|"tw...  214378   3291
# 37346  twinkle vaishnav comedy|"twinkle vaishnav"|"tw...  214378   3291
#
#        dislikes  comment_count  \
# 37224       404            196
# 37346       404            196
#
#                                        thumbnail_link  comments_disabled  \
# 37224  https://i.ytimg.com/vi/iNHecA3PJCo/default.jpg              False
# ...

# %% [markdown]
# **Drop all the duplicate rows from the data**

# %%
help(df.drop_duplicates)
# Out:
# Help on method drop_duplicates in module pandas.core.frame:
#
# drop_duplicates(subset: Union[Hashable, Sequence[Hashable], NoneType] = None, keep: Union[str, bool] = 'first', inplace: bool = False, ignore_index: bool = False) -> Union[ForwardRef('DataFrame'), NoneType] method of pandas.core.frame.DataFrame instance
#     Return DataFrame with duplicate rows removed.
#
#     Considering certain columns is optional. Indexes, including time indexes
#     are ignored.
#
#     Parameters
#     ----------
#     subset : column label or sequence of labels, optional
#         Only consider certain columns for identifying duplicates, by
#         default use all of the columns.
#     keep : {'first', 'last', False}, default 'first'
#         Determines which duplicates (if any) to keep.
#         - ``first`` : Drop duplicates except for the first occurrence.
#         - ``last`` : Drop duplicates except for the last occurrence.
#         - False : Drop all duplicates.
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (33088, 18)

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# **Find the video_id which is having the maximum number of views in the data. Sort the data in descedning order(views) and look into the top row**

# %%
df.sort_values(by = 'views', ascending = False)
# Out:
#           video_id publish_date trending_date      views
# 5407   FlsCjmMhFmw   2017-12-06    2017-12-12  125432237
# 5118   FlsCjmMhFmw   2017-12-06    2017-12-11  113876217
# 4935   FlsCjmMhFmw   2017-12-06    2017-12-10  100911567
# 4476   6ZfuNTqbHE8   2017-11-29    2017-12-07   89930713
# 4235   6ZfuNTqbHE8   2017-11-29    2017-12-06   87449453
# ...            ...          ...           ...        ...
# 5289   p3Wn9FuI2zo   2017-12-10    2017-12-11       5098
# 18319       #NAME?   2018-02-22    2018-02-22       4641
# 20322  18OSLOq-bFA   2018-03-06    2018-03-06       4359
# 29316  iW5ZRboFCMU   2018-05-01    2018-05-01       4287
# 29315  wntggWeDxjI   2018-04-30    2018-05-01       4024
#
# [33088 rows x 4 columns]

# %%
df[df['video_id'] == 'FlsCjmMhFmw'][['video_id', 'publish_date', 'trending_date', 'views']]
# Out:
#          video_id publish_date trending_date      views
# 4458  FlsCjmMhFmw   2017-12-06    2017-12-07   24784863
# 4567  FlsCjmMhFmw   2017-12-06    2017-12-08   52611730
# 4742  FlsCjmMhFmw   2017-12-06    2017-12-09   75969469
# 4935  FlsCjmMhFmw   2017-12-06    2017-12-10  100911567
# 5118  FlsCjmMhFmw   2017-12-06    2017-12-11  113876217
# 5407  FlsCjmMhFmw   2017-12-06    2017-12-12  125432237

# %% [markdown]
# **The data is according to the trending_dates. The number of times, we have a particulr video_id in the data is the number of days the video was on the trending_list**
#
#
# **The data has been captured in such a way that the last row for a particular video is having the latest information.**

# %% [markdown]
# ### Same Day Trending Videos
#
# The videos that were trending on the same day as it was published.
#
#
# publish_date == trending_date
#
# **How many such videos are there?**

# %%
day0 = df[df['trending_date'] == df['publish_date']]

# %%
day0.shape
# Out:
# (441, 18)

# %% [markdown]
# **Find the channel wise count of same day trending videos and identify the top-4 channels with the maximum number of same dat trendingvideos**

# %%
day0['channel_title'].value_counts()
# Out:
# Adda247 :Official Channel of BankersAdda & SSCAdda    48
# WiFiStudy                                             28
# Mahendra Guru : Online Videos For Govt. Exams         16
# Study IQ education                                    12
# T-Series Bhakti Sagar                                 11
#                                                       ..
# Clash of Clans                                         1
# Sheorans                                               1
# Ur IndianConsumer                                      1
# Disney•Pixar                                           1
# Veena's Curryworld                                     1
# Name: channel_title, Length: 193, dtype: int64

# %% [markdown]
# - Education related channels
# - They are really active
# - Frequent live strems
# - Frequent uploads

# %% [markdown]
# **Check for the channel wise sum of views and look into the top-20 channels**

# %%
day0.groupby("channel_title").agg({'views':'sum', 'video_id':'count'}).sort_values(by = 'views', ascending = False).head(20)
# Out:
#                                                        views  video_id
# channel_title
# T-Series                                            13205923         4
# WWE                                                  5308127         6
# Wrestling Phobia                                     3670140         2
# Speed Records                                        2221143         4
# Disney•Pixar                                         1948452         1
# Studio Saraswati Official                            1877699         8
# Mythri Movie Makers                                  1738388         2
# Lahari Music | T-Series                              1646824         1
# Wrestling Time                                       1405443         6
# Jimmy Kimmel Live                                    1401741         1
# Google Developers                                    1375783         1
# Zee News                                             1233669         2
# ...

# %% [markdown]
# ## Analyze T-Series

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc    2017-11-14
# 1  10L1hZ9qa58    2017-11-14
# 2  N1vE8iiEg64    2017-11-14
# 3  kJzGH0PVQHQ    2017-11-14
# 4  il_pSa5l98w    2017-11-14
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 2                     Eruma Saani | Tamil vs English      Eruma Saani
# 3  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
# 4  MCA (Middle Class Abbayi) TEASER - Nani,Sai Pa...         Dil Raju
#
#    category_id              publish_time  \
# 0            1 2017-11-12 12:20:39+00:00
# 1           24 2017-11-12 15:48:08+00:00
# 2           23 2017-11-12 07:08:48+00:00
# 3           24 2017-11-13 01:14:16+00:00
# 4           24 2017-11-10 04:29:50+00:00
#
#                                                 tags    views  likes  \
# ...

# %% [markdown]
# **Drop duplicated rows according to video_id and retain the last row**

# %%
df.shape
# Out:
# (33088, 18)

# %%
df = df.drop_duplicates(subset = 'video_id', keep = 'last')

# %%
df.shape
# Out:
# (16307, 18)

# %% [markdown]
# **Filter the data for channel_title as 'T-Series'.**

# %%
tseries = df[df['channel_title'] =='T-Series']

# %%
tseries.shape
# Out:
# (62, 18)

# %% [markdown]
# - Create a new column 'month' by extracting month for publish_date columns
# - Find the count of videos published per month by T-Series
# - Month in which T-Series posted max number of videos

# %%
tseries['month'] = tseries['publish_date'].dt.month
# Out:
# C:\Users\SUMITH\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tseries['month'].value_counts()
# Out:
# 2     11
# 3     10
# 12     9
# 1      9
# 5      8
# 4      6
# 11     5
# 6      4
# Name: month, dtype: int64

# %% [markdown]
# - No videos were posted for month: 7,8,9,10:
#     - Exam Month
# - Feb: Valentine Month
# - March: Holi Month
# - Dec, Jan: Wedding Season

# %%
tseries[tseries['month'] == 1]
# Out:
#           video_id trending_date  \
# 10062  ZgTKmRPWMq4    2018-01-06
# 10256  TZ4lJABVr3Q    2018-01-07
# 10425  7irWtX1TSRY    2018-01-08
# 10593  KjP7O26saoA    2018-01-09
# 11445  kckDWrICC4s    2018-01-15
# 11993  mPCL6yY2d7U    2018-01-18
# 13170  xvYBg6MWPbM    2018-01-24
# 14000  0B7athiVJBA    2018-01-29
# 14810  v7K4vGYL9zI    2018-02-02
#
#                                                    title channel_title  \
# 10062  Subah Subah (Video) | Arijit Singh, Prakriti K...      T-Series
# 10256  Car Nachdi/Hornn Blow |2 Days To Go |T-Series ...      T-Series
# 10425  Car Nachdi/Hornn Blow | 1Day To Go | T-Series ...      T-Series
# 10593  Car Nachdi/Hornn Blow (Video) | T-Series Mixta...      T-Series
# 11445  NAZAR LAG JAYEGI Video Song | Millind Gaba, Ka...      T-Series
# 11993  Official Teaser: Harjai Song | Maniesh Paul, I...      T-Series
# 13170  Chhote Chhote Peg (Video) | Yo Yo Honey Singh ...      T-Series
# ...
